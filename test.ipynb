# %%
# In your Jupyter notebook
from experiment import train_with_seed, run_full_experiment
from evaluate import evaluate_agent

# Test single training run
net, rewards, metrics = train_with_seed(
    env_name="MsPacman",
    seed=42,
    total_steps=1000,  # Small number for testing
    save_dir='test_results'
)

# Or test full experiment
results = run_full_experiment(
    env_name="MsPacman",
    num_seeds=2,  # Just 2 seeds for testing
    training_steps=1000,
    eval_episodes=10,
    save_dir='test_results'
)
# Out:
# Using device: cpu
#
# ...
# Training with seed 42
# ...
#
# Random seed set to 42
# A.L.E: Arcade Learning Environment (version 0.11.2+ecc1138)
# [Powered by Stella]
# Seed 42: 100%|█████████████████████████████| 1000/1000 [00:02<00:00, 352.47it/s]
# Saved training results to test_results/training_seed_42.pkl
#
# ...
# Training with seed 1
# ...
#
# Random seed set to 1
# Seed 1: 100%|██████████████████████████████| 1000/1000 [00:04<00:00, 247.58it/s]
# Saved training results to test_results/training_seed_1.pkl
#
# ...
# Evaluating agent for 10 episodes
# ...
# Evaluation: 100%|███████████████████████████████| 10/10 [00:03<00:00,  2.91it/s]
# ...
# Training with seed 42
# ...
#
# Random seed set to 42
# Seed 42: 100%|█████████████████████████████| 1000/1000 [00:03<00:00, 329.82it/s]
# Saved training results to test_results/training_seed_42.pkl
#
# ...
# Evaluating agent for 10 episodes
# ...
# Evaluation: 100%|███████████████████████████████| 10/10 [00:04<00:00,  2.47it/s]
# Experiment complete! Results saved to test_results
